# %%
pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 80.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import sweetviz as sv

# %%
data = pd.read_csv('/content/drive/MyDrive/CMPE255_ApacheBeam/Task1/test.csv')

# %%
report = sv.analyze(data)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_html('/content/drive/MyDrive/CMPE255_ApacheBeam/Task1/sweetviz_report.html', open_browser=True, layout='widescreen', scale=1.0)
# Out:
# Report /content/drive/MyDrive/CMPE255_ApacheBeam/Task1/sweetviz_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
